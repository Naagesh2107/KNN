# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report 
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("penguins_size.csv")

# %%
df.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
# 6  Adelie  Torgersen              38.9             17.8              181.0
# 7  Adelie  Torgersen              39.2             19.6              195.0
# 8  Adelie  Torgersen              34.1             18.1              193.0
# 9  Adelie  Torgersen              42.0             20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# ...

# %%
print(df.isnull().sum())
#checking for any null values
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
le = LabelEncoder() 
df['species'] = le.fit_transform(df['species']) 
df['island'] = le.fit_transform(df['island']) 
print(df.head())
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2              39.1             18.7              181.0
# 1        0       2              39.5             17.4              186.0
# 2        0       2              40.3             18.0              195.0
# 3        0       2               NaN              NaN                NaN
# 4        0       2              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
#checking categorical columns values
print("Species column : " , df["species"].unique() )
print("Species column : " , df["island"].unique() )
print("Species column : " , df["sex"].unique() )
# Out:
# Species column :  [0 1 2]
# Species column :  [2 0 1]
# Species column :  ['MALE' 'FEMALE' nan '.']

# %%
filtered = df[ (df["sex"] == ".") | (df["sex"].isna()) ]

df = df.drop(index = filtered.index)

# %%
filtered = df[ (df["sex"] == ".") | (df["sex"].isna()) ]

# %%
print(df.isnull().sum())
#All null values are removed
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
# Distribution of Price
sns.histplot(df['culmen_length_mm'], kde=True)
plt.title('Length vs Frequency')
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.show()

# Distribution of Carat
sns.histplot(df['culmen_depth_mm'], kde=True)
plt.title('Depth vs Frequency')
plt.xlabel('Depth')
plt.ylabel('Frequency')
plt.show()

# Distribution of Carat
sns.histplot(df['flipper_length_mm'], kde=True)
plt.title('flipper_length vs frequency')
plt.xlabel('flipper_length')
plt.ylabel('Frequency')
plt.show()

# Distribution of Carat
sns.histplot(df['body_mass_g'], kde=True)
plt.title('Body Mass vs Frequency')
plt.xlabel('Body Mass')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\naage\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\naage\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\naage\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Distribution of catgorical columns
sns.countplot(x=df['species'])
plt.title('Distribution of species')
plt.xlabel('species')
plt.ylabel('Frequency')
plt.show()

# Distribution of Color
sns.countplot(x=df['island'])
plt.title('Distribution of Island')
plt.xlabel('Island')
plt.ylabel('Frequency')
plt.show()

# %%
sns.pairplot(df, vars=['culmen_length_mm',	'culmen_depth_mm',	'flipper_length_mm',	'body_mass_g'])
plt.show()
# Out:
# C:\Users\naage\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\naage\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\naage\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
Y = df["sex"]
X = df.drop(columns = ["sex"])

# %%
X
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2              39.1             18.7              181.0
# 1          0       2              39.5             17.4              186.0
# 2          0       2              40.3             18.0              195.0
# 4          0       2              36.7             19.3              193.0
# 5          0       2              39.3             20.6              190.0
# ..       ...     ...               ...              ...                ...
# 338        2       0              47.2             13.7              214.0
# 340        2       0              46.8             14.3              215.0
# 341        2       0              50.4             15.7              222.0
# 342        2       0              45.2             14.8              212.0
# 343        2       0              49.9             16.1              213.0
#
#      body_mass_g
# 0         3750.0
# 1         3800.0
# ...

# %%
Y
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 4      FEMALE
# 5        MALE
#         ...
# 338    FEMALE
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 333, dtype: object

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=1)

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Initialize the model 
knn = KNeighborsClassifier() 
# Train the model 
knn.fit(X_train, Y_train) 
# Make predictions 
Y_pred = knn.predict(X_test)

# %%
# Evaluate Logistic Regression 
print("KNN Performance:") 
print(f'Accuracy: {accuracy_score(Y_test, Y_pred)}') 
print(f'Precision: {precision_score(Y_test, Y_pred, average="weighted")}') 
print(f'Recall: {recall_score(Y_test, Y_pred, average="weighted")}') 
print(f'F1-Score: {f1_score(Y_test, Y_pred, average="weighted")}') 
print(classification_report(Y_test, Y_pred))
# Out:
# DecisionTree Performance:
# Accuracy: 0.9047619047619048
# Precision: 0.9097402597402597
# Recall: 0.9047619047619048
# F1-Score: 0.9051977770513238
#               precision    recall  f1-score   support
#
#       FEMALE       0.85      0.94      0.89        36
#         MALE       0.95      0.88      0.91        48
#
#     accuracy                           0.90        84
#    macro avg       0.90      0.91      0.90        84
# weighted avg       0.91      0.90      0.91        84
